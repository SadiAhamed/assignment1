# %% [markdown]
# #                       WEEK 3 ASSIGNMENT
# ## 1.TO READ THE DATASET IN PYTHON ENVIRONMENT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('D:/activity/iris.xls')

# %% [markdown]
# ## 2.DISPLAYING COLOUMN OF DATASET

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# ## 3. CALCULATING MEAN OF EACH COLOUMN OF DATASET

# %%
data.iloc[:,0:4].apply(np.mean)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4.CHECKING FOR THE NULL VALUES PRESENT IN DATASET

# %%
data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ## 5. MEANINGFULL VISUALISATION OF DATASET

# %% [markdown]
# ### a)HISTOGRAM

# %%
plt.figure()
plt.hist(data["SL"],color="red",rwidth=0.9)
plt.title("SL")
plt.xticks()
plt.yticks()
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
data=pd.read_excel('D:/activity/iris.xls')
data.head()
plt.figure(figsize=(10,10))
plt.subplot(4,1,1)
plt.hist(data["SL"],color="red",rwidth=0.9)
plt.title("SL")
plt.xticks()
plt.yticks()

plt.figure(figsize=(10,10))
plt.subplot(4,1,2)
plt.hist(data["SW"],color="blue",rwidth=0.9)
plt.title("SW")
plt.xticks()
plt.yticks()

plt.figure(figsize=(10,10))
plt.subplot(4,1,3)
plt.hist(data["PL"],color="violet",rwidth=0.9)
plt.title("PL")
plt.xticks()
plt.yticks()

plt.figure(figsize=(10,10))
plt.subplot(4,1,3)
plt.hist(data["PW"],color="black",rwidth=0.9)
plt.title("PW")
plt.xticks()
plt.yticks()
plt.tight_layout()

# %% [markdown]
# ### b)PAIRPLOT

# %%
sns.pairplot(data)

# %%
slice_data=data[["SL","PL"]]

# %%
sns.pairplot(slice_data)

# %% [markdown]
# ### c)BOXPLOT

# %%
plt.boxplot(slice_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x200a3dcc4c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x200a3dccb80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x200a3dcc160>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x200a4da8280>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x200a4da85e0>,
# ...
#  'means': []}

# %% [markdown]
# ### d)HEATMAP

# %%
sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SL'),
#   Text(1.5, 0, 'SW'),
#   Text(2.5, 0, 'PL'),
#   Text(3.5, 0, 'PW')])
